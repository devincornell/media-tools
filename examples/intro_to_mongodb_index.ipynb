# %% [markdown]
# # MongoDB Index

# %%
import mediatools

# %%
import pathlib
import pydantic_settings

class Settings(pydantic_settings.BaseSettings):
    mongo_uri: str = "mongodb://127.0.0.1:27017/?directConnection=true"
    db_name: str = "media_archive"
    mongo_index_target: pathlib.Path

settings = Settings()

# %%
import pymongo

async with pymongo.AsyncMongoClient(settings.mongo_uri, serverSelectionTimeoutMS=2000) as client:
    media_index = await mediatools.MediaIndexDB.from_client(client[settings.db_name])

    mindex = await mediatools.MediaIndexDB.from_client(
        client = client[settings.db_name]
    )
    await mindex.update_directory_index(settings.mongo_index_target, verbose=True)
    await mindex.dirs.find_by_path(settings.mongo_index_target)


    print(mindex)
    #await mindex.clear_directory_index(settings.mongo_index_target)
# Out:
# Scanning directories: 100%|████████████████████████████████████████| 18/18 [00:00<00:00, 141.34it/s]
# Indexing videos: 0it [00:00, ?it/s]
# MediaIndexDB(dirs=MediaDirIndexCollection(_collection=AsyncCollection(AsyncDatabase(AsyncMongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True, directconnection=True, serverselectiontimeoutms=2000), 'media_archive'), 'media_dir_index'), collection_name='media_dir_index'), videos=VideoIndexCollection(_collection=AsyncCollection(AsyncDatabase(AsyncMongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True, directconnection=True, serverselectiontimeoutms=2000), 'media_archive'), 'video_file_index'), collection_name='video_file_index'))
